# %% [markdown]
# # PARTIEL Détection et reconnaissance
#
# #### Hugo FAURIEL - IASMSDSEL

# %% [markdown]
# ## Import des librairies

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercice 1

# %% [markdown]
# **On charge notre image**

# %%
image = cv2.imread('gema.jpg')

# %% [markdown]
# **On convertit notre image de BGR (OpenCV) en RGB (matplotlib)**

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %% [markdown]
# **On affiche l'image**

# %%
plt.imshow(image)
plt.axis('off')
plt.title('Image GEMA')
plt.show()

# %% [markdown]
# **On sépare les canneaux de couleur**

# %%
red = image[:, :, 0]
green = image[:, :, 1]
blue = image[:, :, 2]

# %% [markdown]
# **On calcule les dérivées par rapport à x et y**

# %%
dx = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=3)
dy = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=3)

# %% [markdown]
# **On affiche notre image originale suivi des 3 image selon les couleurs**

# %%
plt.figure(figsize=(15, 10))

plt.subplot(1, 4, 1)
plt.imshow(image)
plt.title('Image originale')
plt.axis('off')

plt.subplot(1, 4, 2)
plt.imshow(red)
plt.title('Image rouge')
plt.axis('off')

plt.subplot(1, 4, 3)
plt.imshow(green)
plt.title('Image verte')
plt.axis('off')

plt.subplot(1, 4, 4)
plt.imshow(blue)
plt.title('Image bleue')
plt.axis('off')

plt.show()

# %%
plt.figure(figsize=(15, 10))

plt.subplot(1, 2, 1)
plt.imshow(dx, cmap='gray')
plt.title('Image dérivée par rapport à x')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(dy, cmap='gray')
plt.title('Image dérivée par rapport à y')
plt.axis('off')

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1008.0..1005.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-992.0..996.0].

# %% [markdown]
# **On afiche les 3 logos séparées**

# %%
# On crée notre fonction qui va zoomer sur notre image
def crop_img(img, x, y, w, h):
    return img[y:y+h, x:x+w]

# %%
# On affiche l'image avec les axes
plt.imshow(image)
plt.show()

# %%
# On affiche les 3 logos séparés

width = 200
height = 200

img_iaschool = crop_img(image, 200, 400, width, height)
img_esi = crop_img(image, 500, 400, width, height)
img_cyber = crop_img(image, 800, 400, width, height)

plt.figure(figsize=(15, 10))

plt.subplot(1, 3, 1)
plt.imshow(img_iaschool)
plt.title('Image IA School')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(img_esi)
plt.title('Image ESI')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(img_cyber)
plt.title('Image Cyber')
plt.axis('off')

plt.show()

# %% [markdown]
# ## Exercice 2

# %% [markdown]
# **On convertit nos images en niveau de gris**

# %%
img1 = cv2.imread('img1.png')
img2 = cv2.imread('img2.png')

img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

# %%
fig, ax = plt.subplots()
ax.imshow(img1, cmap='gray')
ax.set_title('Image 1 en niveaux de gris')
ax.axis('off')

# on crée un rectangle au centre de l'image
height, width = img1.shape
center_x, center_y = width // 2, height // 2
rect_width, rect_height = 50, 100
top_left_x, top_left_y = center_x - rect_width // 2, center_y - rect_height // 2

# On affiche le rectangle
rect = plt.Rectangle((top_left_x, top_left_y), rect_width, rect_height, linewidth=2, edgecolor='r', facecolor='none')
ax.add_patch(rect)
plt.show()

# %% [markdown]
# **On affiche les différence de nos images**

# %%
difference = cv2.absdiff(img1, img2)

plt.figure(figsize=(6, 6))
plt.imshow(difference, cmap='gray')
plt.title('Différence absolue entre les deux images')
plt.axis('off')
plt.show()

# %% [markdown]
# **On enregistre l'image contenant les différences**

# %%
cv2.imwrite('difference.png', difference)
# Out:
# True

# %% [markdown]
# **On fait pareil pour les images `maison1.png` et `maison2.png`**

# %%
# On lit nos images
maison1 = cv2.imread('maison1.png')
maison2 = cv2.imread('maison2.png')

# On convertit nos images en niveaux de gris
maison1 = cv2.cvtColor(maison1, cv2.COLOR_BGR2GRAY)
maison2 = cv2.cvtColor(maison2, cv2.COLOR_BGR2GRAY)

# On affiche les différences
diff = cv2.absdiff(maison1, maison2)
plt.figure(figsize=(6, 6))
plt.imshow(diff, cmap='gray')
plt.title('Différence absolue entre les deux images')
plt.axis('off')
plt.show()
